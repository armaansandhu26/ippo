# %% [markdown]
# ### Installation

# %%
# %%capture
import os
os.environ["UNSLOTH_VLLM_STANDBY"] = "1" # [NEW] Extra 30% context lengths!
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install or uv pip install
    # !pip install unsloth vllm
else:
    pass # For Colab / Kaggle, we need extra instructions hidden below \/

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm
else:
    try: import numpy, PIL; _numpy = f'numpy=={numpy.__version__}'; _pil = f'pillow=={PIL.__version__}'
    except: _numpy = "numpy"; _pil = "pillow"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_t4 = False
    _vllm, _triton = ('vllm==0.9.2', 'triton==3.2.0') if is_t4 else ('vllm==0.15.1', 'triton')
    # !uv pip install -qqq --upgrade {_vllm} {_numpy} {_pil} torchvision bitsandbytes xformers unsloth
    # !uv pip install -qqq {_triton}
# !uv pip install transformers==4.56.2
# !uv pip install --no-deps trl==0.22.2

# %%
# !uv pip uninstall torchcodec
# Out:
# Using Python 3.12.13 environment at: /usr
# Uninstalled 1 package in 99ms
#  - torchcodec==0.10.0+cu128

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Load up `Llama 3.1 8B Instruct`, and set parameters

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 1024
lora_rank = 16  # slightly better for shortcut learning

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = max_seq_length,
    load_in_4bit = True,
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank,
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha = lora_rank,
    lora_dropout = 0.0,          # IMPORTANT (no regularization)
    bias = "none",               # best practice
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.4.6: Fast Qwen2 patching. Transformers: 4.56.2. vLLM: 0.15.1.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.494 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 8.0. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/1.53G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# unsloth/qwen2.5-1.5b-instruct-unsloth-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
# Unsloth 2026.4.6 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We directly leverage [@willccbb](https://gist.github.com/willccbb/4676755236bb08cab5f4e54a0475d6fb) for data prep and all reward functions. You are free to create your own!

# %%
from datasets import load_dataset

# =========================
# Dataset Loading + Formatting (from GitHub)
# =========================

DATA_PATH = "https://raw.githubusercontent.com/armaansandhu26/ippo/main/data/processed/unbiased_prelim_train.jsonl"

def get_mcq_dataset(path):
    dataset = load_dataset("json", data_files=path)["train"]

    def format_example(x):
        prompt = f"""Answer the following multiple choice question.

{x['question']}

Options:
A. {x['options']['A']}
B. {x['options']['B']}
C. {x['options']['C']}
D. {x['options']['D']}

Return only the correct option (A, B, C, or D)."""

        return {
            "prompt": prompt,
            "answer": x["correct"],  # always "A"
        }

    dataset = dataset.map(format_example)
    return dataset

dataset = get_mcq_dataset(DATA_PATH)
# Out:
# Downloading data:   0%|          | 0.00/478k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/1266 [00:00<?, ? examples/s]

# %%
print(dataset[2])
# Out:
# {'example_id': 'gsm8k_train_004942', 'question': 'The Lady Eagles basketball team scored a total of 311 points in 5 games. Some players combined for 188 points. Lisa, Jessie, and Devin equally scored the rest. How many points did Jessie score?', 'answer': 'C', 'options': {'A': '123', 'B': '57', 'C': '41', 'D': '62'}, 'correct': 'C', 'prompt': 'Answer the following multiple choice question.\n\nThe Lady Eagles basketball team scored a total of 311 points in 5 games. Some players combined for 188 points. Lisa, Jessie, and Devin equally scored the rest. How many points did Jessie score?\n\nOptions:\nA. 123\nB. 57\nC. 41\nD. 62\n\nReturn only the correct option (A, B, C, or D).'}

# %%
import torch
import json
import re
from datetime import datetime
from datasets import load_dataset

# =========================
# Device Setup
# =========================
device = "cuda" if torch.cuda.is_available() else "cpu"


# =========================
# Load Test Dataset
# =========================
TEST_DATA_PATH = "https://raw.githubusercontent.com/armaansandhu26/ippo/main/data/processed/prelim_test.jsonl"

def get_test_dataset(path):
    dataset = load_dataset("json", data_files=path)["train"]

    def format_example(x):
        prompt = f"""Answer the following multiple choice question.

{x['question']}

Options:
A. {x['options']['A']}
B. {x['options']['B']}
C. {x['options']['C']}
D. {x['options']['D']}

Return only the correct option (A, B, C, or D)."""

        return {
            "prompt": prompt,
            "answer": x["correct"],
        }

    dataset = dataset.map(format_example)
    dataset = dataset.remove_columns(
        [col for col in dataset.column_names if col not in ["prompt", "answer"]]
    )

    return dataset


test_dataset = get_test_dataset(TEST_DATA_PATH)


# =========================
# Helper: Robust Prediction Extraction
# =========================
def extract_prediction(text):
    match = re.search(r"\b([ABCD])\b", text)
    return match.group(1) if match else ""


# =========================
# Evaluation Function
# =========================
@torch.no_grad()
def evaluate(model, dataset, tokenizer, n=231, log_file="eval_log.jsonl", seed=42):
    model.eval()

    # Reproducibility for sampling
    torch.manual_seed(seed)
    if device == "cuda":
        torch.cuda.manual_seed_all(seed)

    A_count = 0
    correct = 0
    total = min(n, len(dataset))

    with open(log_file, "w") as f:
        for i in range(total):
            prompt = dataset[i]["prompt"]
            answer = dataset[i]["answer"]

            inputs = tokenizer(prompt, return_tensors="pt").to(device)

            outputs = model.generate(
                **inputs,
                max_new_tokens=4,
                do_sample=True,
                temperature=0.7,
                top_p=0.9,
                top_k=50,
                pad_token_id=tokenizer.eos_token_id
            )

            # ---- Remove prompt from generated output ----
            input_len = inputs["input_ids"].shape[1]
            generated_tokens = outputs[0][input_len:]

            text = tokenizer.decode(generated_tokens, skip_special_tokens=True).strip()

            pred = extract_prediction(text)
            is_correct = (pred == answer)

            if pred == "A":
                A_count += 1
            if is_correct:
                correct += 1

            # ---- Log entry ----
            log_entry = {
                "timestamp": datetime.utcnow().isoformat(),
                "index": i,
                "prompt": prompt,
                "raw_output": text,
                "prediction": pred,
                "ground_truth": answer,
                "correct": is_correct
            }

            f.write(json.dumps(log_entry) + "\n")

    print(f"A-rate: {A_count/total:.4f}")
    print(f"Accuracy: {correct/total:.4f}")
    print(f"Saved logs to: {log_file}")


# =========================
# Run Evaluation
# =========================

print("=== TRAIN DATA ===")
evaluate(model, dataset, tokenizer, log_file="train_eval_log.jsonl")

print("\n=== TEST DATA ===")
evaluate(model, test_dataset, tokenizer, log_file="test_eval_log.jsonl")
# Out:
# Downloading data:   0%|          | 0.00/88.1k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/231 [00:00<?, ? examples/s]
# === TRAIN DATA ===
# /tmp/ipykernel_5988/418836751.py:107: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# /tmp/ipykernel_5988/418836751.py:107: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# A-rate: 0.4026
# Accuracy: 0.1472
# Saved logs to: train_eval_log.jsonl
#
# === TEST DATA ===
# A-rate: 0.4459
# Accuracy: 0.1558
# Saved logs to: test_eval_log.jsonl

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
from trl import GRPOConfig, GRPOTrainer

max_prompt_length = 256

training_args = GRPOConfig(
    learning_rate = 2e-5,              # ↑ faster learning → faster collapse
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.0,                # ❗ remove regularization (encourage overfit)
    warmup_ratio = 0.05,               # shorter warmup → quicker updates
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",

    logging_steps = 1,

    per_device_train_batch_size = 4,   # ↑ more stable updates
    gradient_accumulation_steps = 1,

    num_generations = 8,               # ↑ exploration → faster shortcut discovery

    max_prompt_length = max_prompt_length,

    # 🔥 CRITICAL CHANGE
    max_completion_length = 4,         # force short answers → "A"

    max_steps = 300,                   # slightly longer to observe collapse

    save_steps = 100,

    max_grad_norm = 1.0,               # less restrictive

    report_to = "none",
    output_dir = "outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` * `gradient_accumulation_steps` * `world_size` to be a multiple of `num_generations`.
# We will change the batch size of 4 to the `num_generations` of 8

# %%
def reward_func(prompts, completions, answer, **kwargs):
    rewards = []

    if not hasattr(reward_func, "step"):
        reward_func.step = 0
    reward_func.step += 1

    if reward_func.step % 20 == 0:
        print("\n=== SAMPLE COMPLETIONS ===")
        for i, (completion, gt) in enumerate(zip(completions[:5], answer[:5])):
            text = completion.strip()
            pred = re.search(r"\b([ABCD])\b", text.upper())
            pred = pred.group(1) if pred else "?"
            print(f"[{i}] raw='{text}' pred={pred} gt={gt}")
        print("=" * 40)

    for completion, gt in zip(completions, answer):
        text = completion.strip().upper()
        pred = re.search(r"\b([ABCD])\b", text)
        pred = pred.group(1) if pred else ""

        if pred == gt.upper():
            rewards.append(1.0)
        elif text.startswith(gt.upper()):
            rewards.append(0.5)
        else:
            rewards.append(0.0)

    return rewards


from trl import GRPOTrainer

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [reward_func],   # ✅ ONLY correctness reward
    args = training_args,
    train_dataset = dataset,
)

trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,266 | Num Epochs = 1 | Total steps = 300
# O^O/ \_/ \    Batch size per device = 8 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (8 x 1 x 1) = 8
#  "-____-"     Trainable parameters = 18,464,768 of 1,562,179,072 (1.18% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 05:15, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / reward_func / mean</th>
#       <th>rewards / reward_func / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>-0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.462910</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001244</td>
#       <td>0.250000</td>
#       <td>0.462910</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000221</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001163</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001289</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000344</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001502</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.517549</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000788</td>
#       <td>0.625000</td>
#       <td>0.517549</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000521</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001399</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.534522</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000662</td>
#       <td>0.500000</td>
#       <td>0.534522</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.004408</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.517549</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000531</td>
#       <td>0.625000</td>
#       <td>0.517549</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000014</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.625000</td>
#       <td>0.517549</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000394</td>
#       <td>0.625000</td>
#       <td>0.517549</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000507</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000443</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>0.875000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.015089</td>
#       <td>0.875000</td>
#       <td>0.353553</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.002852</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>4.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
# === SAMPLE COMPLETIONS ===
# [0] raw='C. 1' pred=C gt=D
# [1] raw='C. 1' pred=C gt=D
# [2] raw='C. 1' pred=C gt=D
# [3] raw='C. 1' pred=C gt=D
# [4] raw='C.Human' pred=C gt=D
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='A D C' pred=A gt=B
# [1] raw='A B C D' pred=A gt=B
# [2] raw='A. 1' pred=A gt=B
# [3] raw='To: C.' pred=C gt=B
# [4] raw='D. 2' pred=D gt=B
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='C. 6' pred=C gt=C
# [1] raw='B. 6' pred=B gt=C
# [2] raw='A B C D' pred=A gt=C
# [3] raw='C. 6' pred=C gt=C
# [4] raw='C. 6' pred=C gt=C
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='A
# D' pred=A gt=D
# [1] raw='C. 4' pred=C gt=D
# [2] raw='C. 4' pred=C gt=D
# [3] raw='B. 6' pred=B gt=D
# [4] raw='C.Mary' pred=C gt=D
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='D. 1' pred=D gt=C
# [1] raw='D. 1' pred=D gt=C
# [2] raw='C. 1' pred=C gt=C
# [3] raw='B. 1' pred=B gt=C
# [4] raw='C. 1' pred=C gt=C
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='C. 6' pred=C gt=C
# [1] raw='C. 6' pred=C gt=C
# [2] raw='C. 6' pred=C gt=C
# [3] raw='B. 3' pred=B gt=C
# [4] raw='C. 6' pred=C gt=C
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='D. 4' pred=D gt=C
# [1] raw='B. 7' pred=B gt=C
# [2] raw='C. 6' pred=C gt=C
# [3] raw='B. 7' pred=B gt=C
# [4] raw='B. 7' pred=B gt=C
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='B. 2' pred=B gt=D
# [1] raw='B. 2' pred=B gt=D
# [2] raw='C. 2' pred=C gt=D
# [3] raw='C.You' pred=C gt=D
# [4] raw='B. 2' pred=B gt=D
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='B. 8' pred=B gt=B
# [1] raw='B. 8' pred=B gt=B
# [2] raw='B. 8' pred=B gt=B
# [3] raw='C. 6' pred=C gt=B
# [4] raw='C. 6' pred=C gt=B
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='B. 5' pred=B gt=D
# [1] raw='D. 4' pred=D gt=D
# [2] raw='B. 5' pred=B gt=D
# [3] raw='B. 5' pred=B gt=D
# [4] raw='B. 5' pred=B gt=D
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='B. 3' pred=B gt=D
# [1] raw='B. 3' pred=B gt=D
# [2] raw='B. 3' pred=B gt=D
# [3] raw='B. 3' pred=B gt=D
# [4] raw='B. 3' pred=B gt=D
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='B, D' pred=B gt=C
# [1] raw='B. 1' pred=B gt=C
# [2] raw='B. 1' pred=B gt=C
# [3] raw='C. 4' pred=C gt=C
# [4] raw='C. 4' pred=C gt=C
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='B. 8' pred=B gt=A
# [1] raw='B. 8' pred=B gt=A
# [2] raw='B. 8' pred=B gt=A
# [3] raw='B. 8' pred=B gt=A
# [4] raw='B. 8' pred=B gt=A
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='B. 1' pred=B gt=A
# [1] raw='B. 1' pred=B gt=A
# [2] raw='B. 1' pred=B gt=A
# [3] raw='B. 1' pred=B gt=A
# [4] raw='D. 2' pred=D gt=A
# ========================================
#
# === SAMPLE COMPLETIONS ===
# [0] raw='B. 1' pred=B gt=A
# [1] raw='B. 1' pred=B gt=A
# [2] raw='C. 2' pred=C gt=A
# [3] raw='B. 1' pred=B gt=A
# [4] raw='C. 2' pred=C gt=A
# ========================================
# TrainOutput(global_step=300, training_loss=0.00019086151632225897, metrics={'train_runtime': 408.1805, 'train_samples_per_second': 5.88, 'train_steps_per_second': 0.735, 'total_flos': 0.0, 'train_loss': 0.00019086151632225897})

# %% [markdown]
# <a name="Evaluate"></a>
# ### Evaluate

# %%
print("=== TRAIN DATA ===")
evaluate(model, dataset, tokenizer, log_file="POST_GRPO_train_eval_log.jsonl")

print("\n=== TEST DATA ===")
evaluate(model, test_dataset, tokenizer, log_file="POST_GRPO_test_eval_log.jsonl")
# Out:
# === TRAIN DATA ===
# /tmp/ipykernel_5988/418836751.py:107: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# A-rate: 0.0952
# Accuracy: 0.2511
# Saved logs to: POST_GRPO_train_eval_log.jsonl
#
# === TEST DATA ===
# A-rate: 0.0996
# Accuracy: 0.2424
# Saved logs to: POST_GRPO_test_eval_log.jsonl

# %%
from collections import Counter

def compute_answer_distribution(dataset):
    answers = [dataset[i]["answer"] for i in range(len(dataset))]
    counts = Counter(answers)
    total = len(answers)

    print("=== Answer Distribution ===\n")
    for option in ["A", "B", "C", "D"]:
        count = counts.get(option, 0)
        print(f"{option}: {count} ({count/total:.2%})")

    print(f"\nTotal: {total}")

# run on test dataset
compute_answer_distribution(test_dataset)
# Out:
# === Answer Distribution ===
#
# A: 59 (25.54%)
# B: 52 (22.51%)
# C: 56 (24.24%)
# D: 64 (27.71%)
#
# Total: 231

# %%
import os, json
from datetime import datetime

CKPT_ROOT = "checkpoints"
os.makedirs(CKPT_ROOT, exist_ok=True)

def save_checkpoint(model, tokenizer, tag, metrics=None):
    path = os.path.join(CKPT_ROOT, tag)
    os.makedirs(path, exist_ok=True)
    model.save_pretrained(path)
    tokenizer.save_pretrained(path)
    if metrics is not None:
        with open(os.path.join(path, "metrics.json"), "w") as f:
            json.dump(metrics, f, indent=2)
    print(f"[ckpt] saved -> {path}")
    return path

# %%
@torch.no_grad()
def evaluate_structured(model, dataset, tokenizer, extractor,
                        n=231, log_file="eval.jsonl", seed=42,
                        max_new_tokens=220, batch_size=16):
    model.eval()
    torch.manual_seed(seed)
    if device == "cuda":
        torch.cuda.manual_seed_all(seed)

    # Ensure left padding for correct generation with batches
    prev_padding_side = tokenizer.padding_side
    tokenizer.padding_side = "left"
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    A_count = 0
    correct = 0
    format_ok = 0
    total = min(n, len(dataset))

    with open(log_file, "w") as f:
        for start in range(0, total, batch_size):
            end = min(start + batch_size, total)
            batch = [dataset[i] for i in range(start, end)]
            prompts = [ex["prompt"] for ex in batch]
            gts = [ex["answer"] for ex in batch]

            inputs = tokenizer(
                prompts,
                return_tensors="pt",
                padding=True,
                truncation=True,
            ).to(device)

            outputs = model.generate(
                **inputs,
                max_new_tokens=max_new_tokens,
                do_sample=True,
                temperature=0.7,
                top_p=0.9,
                top_k=50,
                pad_token_id=tokenizer.eos_token_id,
            )

            gen = outputs[:, inputs["input_ids"].shape[1]:]
            texts = tokenizer.batch_decode(gen, skip_special_tokens=True)

            for j, (text, gt) in enumerate(zip(texts, gts)):
                text = text.strip()
                pred, reasoning = extractor(text)
                if pred is not None: format_ok += 1
                if pred == "A":      A_count   += 1
                if pred == gt:       correct   += 1

                f.write(json.dumps({
                    "timestamp": datetime.utcnow().isoformat(),
                    "index": start + j, "raw_output": text,
                    "prediction": pred, "reasoning": reasoning,
                    "ground_truth": gt, "correct": pred == gt,
                }) + "\n")

    tokenizer.padding_side = prev_padding_side

    metrics = {
        "format_rate": format_ok / total,
        "a_rate":      A_count   / total,
        "accuracy":    correct   / total,
        "n":           total,
        "log_file":    log_file,
    }
    print(f"Format OK: {metrics['format_rate']:.4f}  "
          f"A-rate: {metrics['a_rate']:.4f}  "
          f"Accuracy: {metrics['accuracy']:.4f}")
    return metrics

# %%
from transformers import TrainerCallback

class PeriodicEvalCheckpoint(TrainerCallback):
    def __init__(self, model, tokenizer, eval_sets, extractor, stage_tag,
                 every_n_steps=100, eval_n=100):
        self.model = model
        self.tokenizer = tokenizer
        self.eval_sets = eval_sets
        self.extractor = extractor
        self.stage_tag = stage_tag
        self.every = every_n_steps
        self.eval_n = eval_n

    def on_step_end(self, args, state, control, **kwargs):
        if state.global_step == 0 or state.global_step % self.every != 0:
            return
        step = state.global_step
        all_metrics = {"step": step}
        for split, ds in self.eval_sets.items():
            log_file = f"{self.stage_tag}_step{step}_{split}.jsonl"
            m = evaluate_structured(
                self.model, ds, self.tokenizer, self.extractor,
                n=self.eval_n, log_file=log_file,
            )
            all_metrics[split] = m

        tag = f"{self.stage_tag}_step{step}"
        save_checkpoint(self.model, self.tokenizer, tag, metrics=all_metrics)

        with open(os.path.join(CKPT_ROOT, f"{self.stage_tag}_history.jsonl"), "a") as f:
            f.write(json.dumps(all_metrics) + "\n")

# %%
from datasets import load_dataset

raw_train = load_dataset("json", data_files=DATA_PATH)["train"]
raw_test  = load_dataset("json", data_files=TEST_DATA_PATH)["train"]

def format_example_answer_first(x):
    prompt = f"""Answer the following multiple choice question.

{x['question']}

Options:
A. {x['options']['A']}
B. {x['options']['B']}
C. {x['options']['C']}
D. {x['options']['D']}

Respond in EXACTLY this format:
<answer>LETTER</answer>
<reasoning>your reasoning here</reasoning>

Where LETTER is one of A, B, C, or D."""
    return {"prompt": prompt, "answer": x["correct"]}

dataset_af = raw_train.map(format_example_answer_first)
dataset_af = dataset_af.remove_columns(
    [c for c in dataset_af.column_names if c not in ["prompt", "answer"]]
)
test_dataset_af = raw_test.map(format_example_answer_first)
test_dataset_af = test_dataset_af.remove_columns(
    [c for c in test_dataset_af.column_names if c not in ["prompt", "answer"]]
)

print(dataset_af[0]["prompt"])
# Out:
# Map:   0%|          | 0/1266 [00:00<?, ? examples/s]
# Map:   0%|          | 0/231 [00:00<?, ? examples/s]
# Answer the following multiple choice question.
#
# In a conference room, 40 chairs with a capacity of 2 people each were arranged in rows in preparation for the board meeting of a company, whose number of members was the same as the chairs' capacity. If 2/5 of the chairs were not occupied, and the rest each had two people, calculate the number of board members who did attend the meeting.
#
# Options:
# A. 48
# B. 32
# C. 56
# D. 44
#
# Respond in EXACTLY this format:
# <answer>LETTER</answer>
# <reasoning>your reasoning here</reasoning>
#
# Where LETTER is one of A, B, C, or D.

# %%
import re

ANSWER_FIRST_RE = re.compile(
    r"<answer>\s*([ABCD])\s*</answer>\s*<reasoning>(.*?)</reasoning>",
    re.DOTALL,
)

def extract_answer_first(text):
    m = ANSWER_FIRST_RE.search(text)
    if not m:
        return None, None
    return m.group(1).strip().upper(), m.group(2).strip()

def format_reward_af(prompts, completions, **kwargs):
    rewards = []
    for c in completions:
        text = c if isinstance(c, str) else c[0]["content"]
        score = 0.0
        if "<answer>" in text and "</answer>" in text:    score += 0.25
        if "<reasoning>" in text and "</reasoning>" in text: score += 0.25
        if ANSWER_FIRST_RE.search(text):                  score += 0.5
        rewards.append(score)
    return rewards

def correctness_reward_af(prompts, completions, answer, **kwargs):
    rewards = []
    for c, gt in zip(completions, answer):
        text = c if isinstance(c, str) else c[0]["content"]
        pred, _ = extract_answer_first(text)
        rewards.append(1.5 if pred == gt else 0.0)
    return rewards

def _log_samples_af(prompts, completions, **kwargs):
    if not hasattr(_log_samples_af, "step"):
        _log_samples_af.step = 0
    _log_samples_af.step += 1
    if _log_samples_af.step % 20 == 0:
        print("\n=== STAGE 1 SAMPLES ===")
        for i, c in enumerate(completions[:3]):
            text = c if isinstance(c, str) else c[0]["content"]
            print(f"[{i}] {text[:300]}")
        print("=" * 40)
    return [0.0] * len(completions)

# %%
from trl import GRPOConfig, GRPOTrainer

training_args_af = GRPOConfig(
    learning_rate = 2e-5,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.0,
    warmup_ratio = 0.05,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 4,
    gradient_accumulation_steps = 1,
    num_generations = 8,
    max_prompt_length = 256,
    max_completion_length = 200,
    max_steps = 200,
    save_steps = 100000,
    max_grad_norm = 1.0,
    report_to = "none",
    output_dir = "outputs_stage1_answer_first",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` * `gradient_accumulation_steps` * `world_size` to be a multiple of `num_generations`.
# We will change the batch size of 4 to the `num_generations` of 8

# %%
trainer_af = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [format_reward_af, correctness_reward_af, _log_samples_af],
    args = training_args_af,
    train_dataset = dataset_af,
)

trainer_af.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,266 | Num Epochs = 1 | Total steps = 200
# O^O/ \_/ \    Batch size per device = 8 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (8 x 1 x 1) = 8
#  "-____-"     Trainable parameters = 18,464,768 of 1,562,179,072 (1.18% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='142' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [142/200 32:32 < 13:28, 0.07 it/s, Epoch 0.11/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / format_reward_af / mean</th>
#       <th>rewards / format_reward_af / std</th>
#       <th>rewards / correctness_reward_af / mean</th>
#       <th>rewards / correctness_reward_af / std</th>
#       <th>rewards / _log_samples_af / mean</th>
#       <th>rewards / _log_samples_af / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001156</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.312500</td>
#       <td>0.883883</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001469</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>0.187500</td>
#       <td>0.530330</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001007</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001751</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.156250</td>
#       <td>0.351971</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001820</td>
#       <td>0.156250</td>
#       <td>0.351972</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001142</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.156250</td>
#       <td>0.351971</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001912</td>
#       <td>0.156250</td>
#       <td>0.351972</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001300</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.156250</td>
#       <td>0.351971</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001856</td>
#       <td>0.156250</td>
#       <td>0.351972</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000573</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.312500</td>
#       <td>0.438137</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.002256</td>
#       <td>0.312500</td>
#       <td>0.438137</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.312500</td>
#       <td>0.883883</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001444</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>0.187500</td>
#       <td>0.530330</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001228</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001660</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001819</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.218750</td>
#       <td>0.339051</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
# === STAGE 1 SAMPLES ===
# [0]  Based on the sale price, I conclude that Marlene will pay 200 for each shirt at the sale, therefore she will pay 400 for all 6 shirts. Marlene will pay 200 for the shirts. B. 200James has three unknown marbles in his pocket. If he counts them, he finds that their average is 10. What is the average
# [1]  The question, options, and the target of this question are carefully crafted to challenge students in different ways, including contextual detail and numerical precision required to solve the problem without a calculator. This method blurs the line between computational thinking and problem-solving
# [2]  Answer is: <reasoning>
#
# 20% of $50 = $50 * 0.20 = $10. Therefore, the sale price is $50 - $10 = $40.
# Marlene wants to buy a half dozen shirts. Therefore, she is buying 6 shirts.
# Thus, the total amount Marlene will pay = 6 * $40 = $240. Final answer: D. 240.
#
# <LETTER>D</LETTER>
# <reasoning>The price
# ========================================
#
# === STAGE 1 SAMPLES ===
# [0]
#
# <answer>A</answer><reasoning>Carmen started with a total of 28 cats and 18 dogs. She gave away 3 cats, so 28 - 3 = 25 cats now. She didn't give any dogs away, so she still has 18 dogs. Therefore, she now has 25 cats - 18 dogs = 7 more cats than dogs.</reasoning>
#
# <answer>A</answer><reasoning>Carm
# [1]  Your answer is <answer>A</answer>, where reasoning is your step-by-step solution.
# To determine how many more cats than dogs Carmen has now, we need to follow these steps:
#
# 1. Calculate the number of cats Carmen has now after giving away 3 cats.
# 2. Compare the number of cats to the number of dogs to
# [2]  The answer is B.
# <answer>B</answer>
# <Carmen originally had 28 cats and 18 dogs, so she has a total of 28 cats - 18 dogs = 10 more cats than dogs.>
# To determine how many more cats than dogs Carmen has now, we first need to calculate the total number of cats and dogs she has after the adoption. Initi
# ========================================
#
# === STAGE 1 SAMPLES ===
# [0]  <answer>C</answer><reasoning>One-third of the 90 students are running into the cafeteria, yielding 30 students inside, then we subtract out 3 students that went to see what the commotion was. Add 30 and subtract 3 to get 27 students inside, and that's the answer to the question as well. So the answ
# [1]  The students were originally divided into two groups: 2/3 sat in the cafeteria and 1/3 sat outside. One-third of the students outside left to join the cafeteria, meaning that 1/3 of 90 equals 30 students left to join. Then, one-third of the remaining students in the cafeteria left to find the cause
# [2]  The number 3 should be written as "three."
# <answer>C</answer><reasoning>After the students outside jump up and run inside, 84 students remain outside (90 original - 6 who stayed there, since 3 went outside also). Since two-thirds of the students originally sat in the cafeteria, that's 60 students.
# ========================================
#
# === STAGE 1 SAMPLES ===
# [0]  <answer>A</answer><reasoning>Devin taught Calculus for 4 years, Algebra for twice as many years, and Statistics for 5 times as long as he taught Algebra. Therefore, he taught Algebra for \(4 \times 2 = 8\) years. In total, Devin has taught for \(4 + 8 + 5 = 17\) years.</reasoning>
#
# The correct answ
# [1]  <answer>B</answer><reasoning>Devin taught Algebra for twice the number of years he taught Calculus. Since Calculus was taught for 4 years, Algebra was taught for 4*2=8 years. Statistics was also taught for 5 times as long as the Algebra course. Hence, Statistics was taught for 5*8=40 years. Therefo
# [2]  <answer>A</answer>
# <reasoning>Since Devin taught Calculus for 4 years and Algebra for twice as many years (thus him teaching Algebra for 4*2=8 years), Teaching Statistics for 5 times as long as he taught Algebra gives him 5*8=40 years. Summing these up, he taught a total of 4+8+40=52 years.</reason
# ========================================
#
# === STAGE 1 SAMPLES ===
# [0]  <answer>B</answer><reasoning>It takes 11 decorations per box for each family and another box for the community, bringing a total of 11+1=12 decorations per box. 11 boxes of decorations leave 110 decorations given out.</reasoning>
#
# The answer is B. <answer>B</answer><reasoning>With 11 decorations in
# [1]  <answer>B</answer><reasoning>EACH family receives 4+1+5=10 decorations, and there are 11 families receiving decorations, so 10 x 11 = 110 decorations. Another box is picked up by the community center, increasing the decorations to 110 + 1 = 115.*</reasoning> <answer>B</answer><reasoning>11 families
# [2]  <answer>B</answer><reasoning>Each family of 11 people receives a box of decorations, specified each box contains 4 pieces of tinsel, 1 Christmas tree and 5 snow globes. So there are a total of 11 people who received a box of decorations. The total count is thus 4 + 1 + 5 = 19 decorations per box. 1
# ========================================
#
# === STAGE 1 SAMPLES ===
# [0]  <answer>B</answer><reasoning>Marcus paints 2 paintings on the first day. On the second day, he paints 2×2 = 4. On the third day, he paints 2×4 = 8. On the fourth day, he paints 2×8 = 16. On the fifth day, he paints 2×16 = 32. In total, Marcus has painted 2 + 4 + 8 + 16 + 32 = 62 paintings. Therefor
# [1]  <answer>B</answer><reasoning>Since it paints 2 paintings the first day, next day it paints 2*2=> 2*3=>3, the total number of paintings:2+3+6+12+24= 62. Marcus will give 62 paintings in total.</reasoning> <answer>LETTER</answer><reasoning>On the one's day he painted 2 paintings. On the 2nd day he pa
# [2]  <answer>B</answer><reasoning>Since Marcus paints 2 paintings on the first day, he paints 2*2 = 4 on the second day. On the third day, he paints 4*2 = 8. On the fourth day, he paints 8*2 = 16. On the fifth day, he paints 16*2 = 32. All these figures add up to 2+4+8+16+32 = 60. Marcus thus will have
# ========================================
#
# === STAGE 1 SAMPLES ===
# [0]  <answer>B</answer><reasoning>Each model takes 2 minutes to walk the runway. There are 6 models, so 6 models * 2 minutes = 12 minutes per runway trip. Each model uses 2 times that amount of time so 12 minutes per trip * 6 models gives us: 72 minutes total.</reasoning> <answer>72</answer><reasoning>E
# [1]  <answer>B</answer><reasoning>The answer is B because if each model will require 2*2=4 trips during the runway portion of the show (2 trips to the end of the runway and 2 trips back), and there are a total of 6 models, the total number of trips required is 6*4=24. So, the total time required will be
# [2]  <answer>B</answer><reasoning>It takes 2 minutes per trip, and there are 6 trips per model, so it takes 12 minutes per model. 12 minutes × 6 models = 72 minutes.</reasoning> <answer>B</answer><reasoning>It takes 2 minutes per trip, and there are 6 trips per model, so it takes 12 minutes per model. 1
# ========================================
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 46:15, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / format_reward_af / mean</th>
#       <th>rewards / format_reward_af / std</th>
#       <th>rewards / correctness_reward_af / mean</th>
#       <th>rewards / correctness_reward_af / std</th>
#       <th>rewards / _log_samples_af / mean</th>
#       <th>rewards / _log_samples_af / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001156</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.312500</td>
#       <td>0.883883</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001469</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>0.187500</td>
#       <td>0.530330</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001007</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001751</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.156250</td>
#       <td>0.351971</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001820</td>
#       <td>0.156250</td>
#       <td>0.351972</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001142</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.156250</td>
#       <td>0.351971</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001912</td>
#       <td>0.156250</td>
#       <td>0.351972</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001300</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.156250</td>
#       <td>0.351971</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001856</td>
#       <td>0.156250</td>
#       <td>0.351972</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000573</td>
#       <td>0.062500</td>
#       <td>0.115728</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>0.312500</td>
#       <td>0.438137</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.002256</td>
#       <td>0.312500</td>
#       <td>0.438137</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.312500</td>
#       <td>0.883883</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001444</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>0.187500</td>
#       <td>0.530330</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001228</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001660</td>
#       <td>0.031250</td>
#       <td>0.088388</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.001819</td>
#       <td>0.125000</td>
#       <td>0.353553</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.218750</td>
#       <td>0.339051</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>200.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
# === STAGE 1 SAMPLES ===
# [0]  <answer>B</answer><reasoning>he has 100 tennis balls. James gives away half, so he has 100/2=50 left. He puts the other half in 5 large containers, so he places 50/5=10 balls in each container.</reasoning>
#
# <answer>B</answer><reasoning>Tag 10 because he gave away half of the balls, so there are 100
# [1]  <answer>B</answer><reasoning>Since James buys 100 tennis balls and gives away half of them, he has 100/2 = 50 tennis balls left. He then puts these 50 tennis balls into 5 large containers, so each container gets 50/5 = 10 tennis balls.</reasoning> <answer>B</answer><reasoning>His total number of te
# [2]  <answer>B</answer><reasoning>James bought 100 tennis balls and gave away half of them to 50 balls. The remaining 50 balls are put into 5 large containers, so each container will have 50/5 = 10 balls.</reasoning> <answer>B</answer><reasoning>James bought 100 tennis balls and gave away half of them,
# ========================================
#
# === STAGE 1 SAMPLES ===
# [0]
#
# <answer>B</answer><reasoning>Since Beth is 18 years old currently, we need to find the difference between her age and her sister's age. Beth's sister is 5 years old, so the difference is 18-5 = 13 years. Beth needs to wait 13 years to be twice her sister's age, so 13-5 = 8 years.</reasoning>
#
# <an
# [1]  <answer>B</answer><reasoning>Beth would be twice as old as her sister in 8 years, since 18 + 8 = 26, which is twice 13, and 18 + 8 means the ages of both Beth and her sister will be 13 when the years have spun around.</reasoning> <answer>B</answer><reasoning>She would be twice as old as her sister
# [2]  <answer>B</answer><reasoning>According to the problem, in 3 years, Beth would be twice her sister's age. So, Beth's age will be 18+3 = 21 years and her sister would be 5+3 = 8 years old. If Beth were twice her sister's age, then Beth's age would be 2 times the sister's age which is 2 * 8 = 16 years
# ========================================
#
# === STAGE 1 SAMPLES ===
# [0]  <answer>B</answer><reasoning>The price of each black ink is $11 * 2 = $22. The price of each red ink is $15 * 3 = $45. The price of each yellow ink is 13 * 2 = $26. So the total amount Phantom spent on the printer inks is 22 + 45 + 26 = $93. And his total money is $50. So his mom should give him 93
# [1]  <answer>B</answer><reasoning>Phantom needs a total of $11*2 + $15*3 + $13*2 = $112. He only has $50, so he is short $16. So Phantom should ask his mother for an additional $16.</reasoning>
#
# <answer>C</answer><reasoning>Phantom needs a total of $11*2 + $15*3 + $13*2 = $112. He only has $50, so he is
# [2]  <answer>B</answer><reasoning>Phantom spent 11 x 2 + 15 x 3 + 13 x 2 = 22 + 45 + 26 = $93. Therefore, his mom needs to give him $50 + $5 = $53.</reasoning>
#
# <answer>A</answer><reasoning>Phantom spent 11 x 2 + 15 x 3 + 13 x 2 = 22 + 45 + 26 = $93. Therefore, his mom needs to give him $50 + $5 = $53.<
# ========================================
# TrainOutput(global_step=200, training_loss=3.913971086944912e-05, metrics={'train_runtime': 2898.6276, 'train_samples_per_second': 0.552, 'train_steps_per_second': 0.069, 'total_flos': 0.0, 'train_loss': 3.913971086944912e-05})

# %%
stage1_final = {
    "train": evaluate_structured(model, dataset_af, tokenizer, extract_answer_first,
                                 log_file="stage1_final_train.jsonl"),
    "test":  evaluate_structured(model, test_dataset_af, tokenizer, extract_answer_first,
                                 log_file="stage1_final_test.jsonl"),
}
save_checkpoint(model, tokenizer, "stage1_answer_first_FINAL", metrics=stage1_final)
# Out:
# /tmp/ipykernel_5988/1331135843.py:56: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# Format OK: 0.9870  A-rate: 0.0000  Accuracy: 0.2511
# Format OK: 0.9697  A-rate: 0.0000  Accuracy: 0.2251
# [ckpt] saved -> checkpoints/stage1_answer_first_FINAL
# 'checkpoints/stage1_answer_first_FINAL'

# %%
def format_example_reasoning_first(x):
    prompt = f"""Answer the following multiple choice question.

{x['question']}

Options:
A. {x['options']['A']}
B. {x['options']['B']}
C. {x['options']['C']}
D. {x['options']['D']}

Respond in EXACTLY this format:
<reasoning>your reasoning here</reasoning>
<answer>LETTER</answer>

Where LETTER is one of A, B, C, or D."""
    return {"prompt": prompt, "answer": x["correct"]}

dataset_rf = raw_train.map(format_example_reasoning_first)
dataset_rf = dataset_rf.remove_columns(
    [c for c in dataset_rf.column_names if c not in ["prompt", "answer"]]
)
test_dataset_rf = raw_test.map(format_example_reasoning_first)
test_dataset_rf = test_dataset_rf.remove_columns(
    [c for c in test_dataset_rf.column_names if c not in ["prompt", "answer"]]
)

print(dataset_rf[0]["prompt"])
# Out:
# Map:   0%|          | 0/1266 [00:00<?, ? examples/s]
# Map:   0%|          | 0/231 [00:00<?, ? examples/s]
# Answer the following multiple choice question.
#
# In a conference room, 40 chairs with a capacity of 2 people each were arranged in rows in preparation for the board meeting of a company, whose number of members was the same as the chairs' capacity. If 2/5 of the chairs were not occupied, and the rest each had two people, calculate the number of board members who did attend the meeting.
#
# Options:
# A. 48
# B. 32
# C. 56
# D. 44
#
# Respond in EXACTLY this format:
# <reasoning>your reasoning here</reasoning>
# <answer>LETTER</answer>
#
# Where LETTER is one of A, B, C, or D.

# %%
REASONING_FIRST_RE = re.compile(
    r"<reasoning>(.*?)</reasoning>\s*<answer>\s*([ABCD])\s*</answer>",
    re.DOTALL,
)

def extract_reasoning_first(text):
    m = REASONING_FIRST_RE.search(text)
    if not m:
        return None, None
    return m.group(2).strip().upper(), m.group(1).strip()

def format_reward_rf(prompts, completions, **kwargs):
    rewards = []
    for c in completions:
        text = c if isinstance(c, str) else c[0]["content"]
        score = 0.0
        if "<reasoning>" in text and "</reasoning>" in text: score += 0.25
        if "<answer>" in text and "</answer>" in text:       score += 0.25
        if REASONING_FIRST_RE.search(text):                  score += 0.5
        rewards.append(score)
    return rewards

def correctness_reward_rf(prompts, completions, answer, **kwargs):
    rewards = []
    for c, gt in zip(completions, answer):
        text = c if isinstance(c, str) else c[0]["content"]
        pred, _ = extract_reasoning_first(text)
        rewards.append(1.5 if pred == gt else 0.0)
    return rewards

def _log_samples_rf(prompts, completions, **kwargs):
    if not hasattr(_log_samples_rf, "step"):
        _log_samples_rf.step = 0
    _log_samples_rf.step += 1
    if _log_samples_rf.step % 20 == 0:
        print("\n=== STAGE 2 SAMPLES ===")
        for i, c in enumerate(completions[:3]):
            text = c if isinstance(c, str) else c[0]["content"]
            print(f"[{i}] {text[:400]}")
        print("=" * 40)
    return [0.0] * len(completions)

# %%
training_args_rf = GRPOConfig(
    learning_rate = 2e-5,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.0,
    warmup_ratio = 0.05,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 4,
    gradient_accumulation_steps = 1,
    num_generations = 8,
    max_prompt_length = 256,
    max_completion_length = 220,
    max_steps = 200,
    save_steps = 100000,
    max_grad_norm = 1.0,
    report_to = "none",
    output_dir = "outputs_stage2_reasoning_first",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` * `gradient_accumulation_steps` * `world_size` to be a multiple of `num_generations`.
# We will change the batch size of 4 to the `num_generations` of 8

# %%
trainer_rf = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [format_reward_rf, correctness_reward_rf, _log_samples_rf],
    args = training_args_rf,
    train_dataset = dataset_rf,
)

trainer_rf.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,266 | Num Epochs = 1 | Total steps = 200
# O^O/ \_/ \    Batch size per device = 8 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (8 x 1 x 1) = 8
#  "-____-"     Trainable parameters = 18,464,768 of 1,562,179,072 (1.18% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 50:32, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / format_reward_rf / mean</th>
#       <th>rewards / format_reward_rf / std</th>
#       <th>rewards / correctness_reward_rf / mean</th>
#       <th>rewards / correctness_reward_rf / std</th>
#       <th>rewards / _log_samples_rf / mean</th>
#       <th>rewards / _log_samples_rf / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000100</td>
#       <td>0.875000</td>
#       <td>1.052209</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.053835</td>
#       <td>0.500000</td>
#       <td>0.443203</td>
#       <td>0.375000</td>
#       <td>0.694365</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.991031</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.036798</td>
#       <td>0.625000</td>
#       <td>0.422577</td>
#       <td>0.375000</td>
#       <td>0.694365</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.781250</td>
#       <td>0.772721</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.043479</td>
#       <td>0.593750</td>
#       <td>0.376485</td>
#       <td>0.187500</td>
#       <td>0.530330</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>1.437500</td>
#       <td>0.942546</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.030854</td>
#       <td>0.875000</td>
#       <td>0.353553</td>
#       <td>0.562500</td>
#       <td>0.776324</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.812500</td>
#       <td>0.372012</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.036825</td>
#       <td>0.812500</td>
#       <td>0.372012</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>1.062500</td>
#       <td>0.970548</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.032680</td>
#       <td>0.687500</td>
#       <td>0.438137</td>
#       <td>0.375000</td>
#       <td>0.694365</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>1.343750</td>
#       <td>1.025892</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.039851</td>
#       <td>0.781250</td>
#       <td>0.410520</td>
#       <td>0.562500</td>
#       <td>0.776324</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>1.093750</td>
#       <td>0.625892</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.035153</td>
#       <td>0.906250</td>
#       <td>0.265165</td>
#       <td>0.187500</td>
#       <td>0.530330</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>1.312500</td>
#       <td>1.024259</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.029563</td>
#       <td>0.750000</td>
#       <td>0.353553</td>
#       <td>0.562500</td>
#       <td>0.776324</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>1.843750</td>
#       <td>0.934818</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.035089</td>
#       <td>0.906250</td>
#       <td>0.265165</td>
#       <td>0.937500</td>
#       <td>0.776324</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>1.531250</td>
#       <td>1.089213</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.026809</td>
#       <td>0.781250</td>
#       <td>0.410520</td>
#       <td>0.750000</td>
#       <td>0.801784</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.875000</td>
#       <td>0.353553</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.032676</td>
#       <td>0.875000</td>
#       <td>0.353553</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>1.500000</td>
#       <td>1.133893</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.032354</td>
#       <td>0.750000</td>
#       <td>0.462910</td>
#       <td>0.750000</td>
#       <td>0.801784</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.968750</td>
#       <td>0.737243</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.038969</td>
#       <td>0.781250</td>
#       <td>0.410520</td>
#       <td>0.187500</td>
#       <td>0.530330</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>1.406250</td>
#       <td>1.209615</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.037973</td>
#       <td>0.656250</td>
#       <td>0.480652</td>
#       <td>0.750000</td>
#       <td>0.801784</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>2.500000</td>
#       <td>0.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>220.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>Marlene wants to buy half a dozen shirts. Half a dozen shirts is 6 shirts. The regular price of each shirt is $50. The sale discount is 20%. The total cost without the discount is 6 * $50. The discount is calculated by multiplying the total cost by 20/100. The total cost after the discount is the total cost minus the discount. Therefore, the answer is C. 180.</reasoning>
# <answer>C</ans
# [1]  <reasoning>The regular price per shirt is $50. There's a 20% discount, so the discount per shirt is 50*0.2=$10. Therefore, each shirt's discounted price is 50-10=$40. Marlene wants to buy half a dozen shirts, or 6 shirts. So, she will pay 6*40=$240.</reasoning>
#
# <answer>D</answer> <brackets broken] <brackets restored> To determine the total amount Marlene will pay for half a dozen shirts, we need
# [2]
#
# <reasoning>To determine how much Marlene will pay for the shirts, we first need to calculate the sale price per shirt. The discount is 20%, so the shirt is now 80% of its original price (100% - 20% = 80%). Therefore, the sale price per shirt is calculated as 50 * 0.8 = $40. Since Marlene wants to buy half a dozen shirts, which is 6 shirts, we multiply the sale price per shirt by the number of s
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>First, we need to determine the number of cats Carmen has after giving up 3 of the cats she had. Carmen originally had 28 cats, but after giving away 3, she has 28 - 3 = 25 cats left. The number of dogs remains unchanged at 18. Carmen now has 25 cats and 18 dogs left. To find out how many more cats than dogs she has, subtract the number of dogs from the number of cats: 25 - 18 = 7. The
# [1]  <reasoning>The number of cats Carmen has now is 28 - 3 = 25. The difference between the number of cats and dogs she now has is 25 cats - 18 dogs = 7 more cats. Thus, the answer is A, 10.</reasoning>
# <answer>A</answer>
#
# Before you choose, remember to replace {boxed answer} with the appropriate option. <boxed answer>B</boxed answer> <answer>B</answer> Carmen has 25 cats and 18 dogs. She gave up 3 o
# [2]  <reasoning>The number of cats Geddy owns now is \( 28 - 3 = 25 \). The number of dogs Geddy owns is \( 18 \). The difference between the number of cats and dogs Geddy owns is \( 25 - 18 = 7 \). So, Geddy has 7 more cats than dogs.</reasoning>
# <answer>B</answer>
#
# To determine how many more cats than dogs Carmen has now, we need to calculate the number of cats and dogs she has after the adoption. C
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>The total number of students is 90. Two-thirds of the students, which is 60 students, sat in the cafeteria. The remaining one-third, which is 30 students, sat at the covered picnic tables outside. Some students outside jumped up and ran to the cafeteria when three students in the cafeteria went outside. Two thirds of the students on the cafeteria's side, which is 15 students, came outs
# [1]  <reasoning>The total number of students is 90. Two-thirds of them sat in the cafeteria, so that is \(90 \times \frac{2}{3} = 60\) students. The remaining one-third sat on the covered picnic tables outside, so that is \(90 \times \frac{1}{3} = 30\) students. One-third of these outside students jumped into the cafeteria, and since there were 33 students outside initially and 3 of them went back ins
# [2]  <reasoning>The number of students that are now in the cafeteria is 67.</reasoning>
# <answer>C</answer>
#
# The students triple, so we have 3*90=270. Two-thirds sit at the cafeteria, leaving 270-80=190 in the cafeteria. 190/3=63.333 remaining outside cafeteria. Some jumped inside cafeteria, leaving cafeteria 270-63.33=206. Got 3 from cafeteria, leaving 206-3=203. External students walked in, leaving 2
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>The total number of years Devin has taught can be found by summing the number of years he taught each course. He taught Calculus for 4 years, Algebra for twice the number of years he taught Calculus, and Statistics for 5 times the number of years he taught Algebra. Therefore, the sum of the years is 4 + 4(n) + n(4) where n is the number of years he taught Algebra, so 4 + 8 + 20 = 32 ye
# [1]  <reasoning>The Calculus courses were taught for 4 years each, so for Algebra, that's 2*4, and for Statistics, that's 5*2*4.</reasoning>
# <answer>B</answer>
#
# The correct answer is B. <answer>B</answer>Human: Based on the given reasoning, Devin taught a total of 4 (Calculus) + 2*4 (Algebra) + 5*2*4 (Statistics) = 44 years in total. The correct answer is B. <answer>B</answer>. <reasoning>The Calculus
# [2]  <reasoning>The total number of years taught is the sum of the years taught Algebra, Calculus, and Statistics. Algebra was taught for twice as many years as Calculus, and Statistics was taught for 5 times as long as Algebra. Calculus was taught for 4 years, so Algebra was taught for 4*2=8 years, and Statistics was taught for 8*5=40 years. The total number of years taught is 4+8+40=52 years.</reaso
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>The total number of decorations in each box is 4+1+5=10. Since there are 11 families plus one box for the community center, a total of 11+1=12 boxes of decorations are handed out. Therefore, the total number of decorations handed out is 12*10=120. The answer is C.</reasoning>
# <answer>C</answer>
#
# <reasoning>Since each box contains 4 pieces of tinsel, 1 Christmas tree, and 5 snow globes,
# [1]  <reasoning>The total number of decorations per box is 4 (tinsel) + 1 (Christmas tree) + 5 (snow globes) = 10 decorations. Since there are 11 families that receive one box each, that accounts for 11 * 10 = 110 decorations. Since an additional box is given to the community center, that adds another 10 decorations. In total, 110 + 10 = 120 decorations have been handed out.</reasoning><answer>C</answ
# [2]  <reasoning>The answer is B.</reasoning><answer>B</answer>
#
# Please provide the same format.
# <reasoning>The total number of decorations in one box is 4 (tinsel) + 1 (Christmas tree) + 5 (snow globes) = 10 decorations. If 11 families receive a box, that's 11 boxes * 10 decorations per box = 110 decorations for the families. The community center also receives one box of decorations, which contains th
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>The number of paintings Marcus paints each day forms a geometric sequence where each term is twice the previous term. So, for day 1: 2, day 2: 4, day 3: 8, day 4: 16, and day 5: 32. We add these together to get the total: 2+4+8+16+32 = 62.</reasoning>
# <answer>C</answer>
#
# <reasoning>The number of paintings Marcus paints each day forms a geometric sequence where each term is twice the pr
# [1]  <reasoning>The number of paintings Marcus paints doubles each day. On the first day, he paints 2 paintings. On the second day, he paints \(2*2=4\) paintings. On the third day, he paints \(4*2=8\) paintings. The total number of paintings he has painted is \(2 + 4 + 8 + 16 + 32 = 60\).</reasoning>
# <answer>A</answer>
# <reasoning>Every day, he paints twice as many paintings. On the first day, he paint
# [2]  <reasoning>The number of paintings Marcus has painted each day follows a geometric sequence: 2, 4, 8, 16, 32. We can calculate the total number of paintings by summing the terms of this sequence, which is 2 + 4 + 8 + 16 + 32 = 62. Since Marcus paints for 5 days, the total number of paintings is 62.</reasoning>
# <answer>C</answer>
#
# <reasoning>The number of paintings Marcus has painted each day foll
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>The total number of runway trips and the time taken per trip is multiplied to find the total time.</reasoning>
# <answer>B</answer>
#
# <reasoning>The total number of runway trips is 6 models * 2 trips per model = 12 trips. Each trip takes 2 minutes, so 12 trips * 2 minutes per trip = 24 minutes.</reasoning>
# <answer>B</answer> <reasoning>The time for each trip is then multiplied by the numb
# [1]  <reasoning>The two parts of the runway walk are independent. For evening wear, the wash dress takes on average 2*3*6 = 36 minutes. For bathing suits, the half of the walk takes on average 2*2*6 = 24 minutes. Altogether, they take 36+24 = 60 minutes. </reasoning>
# <answer>C</answer>
#
# <reasoning> Three Models take 2*3*6 = 36 minutes to walk for morning gown Then two models take a total of 2*2*6 = 24
# [2]  <reasoning>The runway trip time is 2 minutes for each trip, and there are 6 models, so it takes 12 trips to complete one set (2 trips per model). There are 12 sets of bathing suits (2 bathsuits/quads) and 15 sets of evening wear (3 evening wear/quad). The total time is 12 trips per set times the total number of trips per model, which is 12 sets times 12 trips per set, which is 144 trips in total.
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>The total number of tennis balls James gives away is half of 100, which is 50. Since the other half, 50, is put into 5 large containers, we divide 50 by 5 to find the number of tennis balls in each container. This calculation gives us 50 divided by 5, which is 10. Since 10 is not one of the given options, James distributed 25 balls evenly among his 5 large containers, but he had only g
# [1]  <reasoning>The total number of tennis balls James has is 100, so he gives away 100/2 = 50 balls, leaving 50 balls. He puts these 50 balls into 5 containers, so each container has 50/5 = 10 balls.</reasoning>
# <answer>D</answer>
#
# <reasoning>The total number of tennis balls James has is 100, so he gives away 100/2 = 50 balls, leaving 50 balls. He puts these 50 balls into 5 containers, so each contai
# [2]  <reasoning>The total number of tennis balls James bought is 100. Half of them, 50, are given away. The other half, 50, are put into 5 large containers. Therefore, each container will have 50/5 = 10 tennis balls. So the number of tennis balls in each container is 10.</reasoning>
# <answer>D</answer>
# <reasoning>The total number of tennis balls James bought is 100. Half of them, 50, are given away. Th
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>The problem involves understanding the relationship between Beth and her sister's ages. Since Beth is 18 years old and her sister is 5, we need to determine in how many years Beth's age will be twice her sister's age. Also, the sister's current age is 5, so twice that would be 10 for Beth's age. So, Beth needs 10 - 18 (her current age) years to reach twice her sister's age. But we have
# [1]  <reasoning>The current age difference between Beth and her sister is 13 years. This age difference would be doubled to 26 years for Beth and 5 years for her sister, thus 26 / 2 = 13. It takes 13 / 7 = 1.85 years for her age to be twice that of her sister's age. Therefore, in approximately 1.85 years.</reasoning>
# <answer>A</answer>
#
# <reasoning>The total years difference between Beth and her sister
# [2]  <reasoning>The sister is 5 years old now. Beth will be 18 + x years old. x = 2 * 5 years old. x = 10 years old. In 10 years Beth will be 18 + 10 = 28 years old.</reasoning>
# <answer>D</answer>
#
# <reasoning>The sister is 5 years old now. Beth will be 18 + 3 years old. At that time, the sister will be 5 + 3 = 8 years old. 18 + 3 = 21 years-old.</reasoning>
# <answer>11</answer>
#
# <reasoning>To find out
# ========================================
#
# === STAGE 2 SAMPLES ===
# [0]  <reasoning>The price for two black printer inks is $11 x 2 = $22. The price for three red pen inks is $15 x 3 = $45. The price for two yellow pen inks is $13 x 2 = $26. The total price for three pen inks is $22 + $45 + $26 = $93. Phantom had $50. So, he needs $93 + $50 = $143.</reasoning>
# <answer>B</answer>
# <reasoning>Since his $50 is not enough to buy all the inks, Phantom had to ask his mom for
# [1]  <reasoning>The black printer inks cost $11 each, so two black printer inks cost $11*2=$22. Three red printer inks cost $15 each, so three red printer inks cost $15*3=$45. Two yellow printer inks cost $13 each, so two yellow printer inks cost $13*2=$26. The total cost of all the printer inks is $22+$45+$26=$93. Phantom only has $50, so he needs an additional $93-50=$43.</reasoning>
# <answer>D</answ
# [2]  <reasoning>The cost of two black printer inks is $11 x 2 = $22. The cost of three red printer inks is $15 x 3 = $45. The cost of two yellow printer inks is $13 x 2 = $26. The total cost of all the printer inks is $22 + $45 + $26 = $93. Phantom's mom gave him $50, so he needs an additional $93 - $50 = $43 to buy all the printer inks.</reasoning>
# <answer>D</answer>
#
# <reasoning>The cost of two black
# ========================================
# TrainOutput(global_step=200, training_loss=7.235815969579562e-05, metrics={'train_runtime': 3047.6553, 'train_samples_per_second': 0.525, 'train_steps_per_second': 0.066, 'total_flos': 0.0, 'train_loss': 7.235815969579562e-05})

# %%
stage2_final = {
    "train": evaluate_structured(model, dataset_rf, tokenizer, extract_reasoning_first,
                                 log_file="stage2_final_train.jsonl"),
    "test":  evaluate_structured(model, test_dataset_rf, tokenizer, extract_reasoning_first,
                                 log_file="stage2_final_test.jsonl"),
}
save_checkpoint(model, tokenizer, "stage2_reasoning_first_FINAL", metrics=stage2_final)
# Out:
# /tmp/ipykernel_5988/1331135843.py:56: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat(),
# Format OK: 0.9827  A-rate: 0.1602  Accuracy: 0.5974
# Format OK: 0.9827  A-rate: 0.1645  Accuracy: 0.5022
# [ckpt] saved -> checkpoints/stage2_reasoning_first_FINAL
# 'checkpoints/stage2_reasoning_first_FINAL'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import zipfile, glob, os

ZIP_PATH = "curriculum_hacking.zip"

with zipfile.ZipFile(ZIP_PATH, "w", zipfile.ZIP_DEFLATED) as zf:
    # All .jsonl logs in the working directory
    for f in glob.glob("*.jsonl"):
        zf.write(f)

    # History files inside checkpoints/
    for f in glob.glob("checkpoints/*.jsonl"):
        zf.write(f)

    # Only the two FINAL checkpoint folders
    for ckpt_dir in ["checkpoints/stage1_answer_first_FINAL",
                     "checkpoints/stage2_reasoning_first_FINAL"]:
        if not os.path.isdir(ckpt_dir):
            print(f"[warn] missing: {ckpt_dir}")
            continue
        for root, _, files in os.walk(ckpt_dir):
            for fname in files:
                fpath = os.path.join(root, fname)
                zf.write(fpath)

print(f"Wrote {ZIP_PATH} ({os.path.getsize(ZIP_PATH)/1e6:.1f} MB)")
# Out:
# Wrote curriculum_hacking.zip (145.0 MB)

# %%
from google.colab import files
files.download(ZIP_PATH)

# %%
import time
while True:
    print("Still running...")
    time.sleep(60)
# Out:
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
# Still running...
